# %% [markdown]
# <a href="https://colab.research.google.com/github/Nayumt99/dados_py_pandas/blob/main/Pyandpandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Passo 1: Importação das Bibliotecas
import pandas as pd

# Passo 2: Carregamento dos Dados
# Substitua 'caminho_para_arquivo.csv' pelo caminho onde você salvou o arquivo CSV
df = pd.read_csv('tabela.csv')

# Passo 3: Análise Exploratória de Dados (EDA)
# Visualizar as primeiras linhas dos dados
print("Primeiras 5 linhas do DataFrame:")
print(df.head())

# Verificar o resumo estatístico
print("\nResumo estatístico do DataFrame:")
print(df.describe())

# Verificar se há valores nulos ou faltantes
print("\nValores nulos por coluna:")
print(df.isnull().sum())

# Passo 4: Análise de Vendas
# Exemplo de análise de vendas ao longo do tempo
# Substitua 'data_coluna' pelo nome da coluna que contém as datas de vendas
# e 'valor_coluna' pelo nome da coluna que contém os valores de venda
vendas_por_data = df.groupby('data_venda')['preco'].sum()
print("\nVendas ao longo do tempo:")
print(df.columns)

# Passo 5: Visualização de Dados
import matplotlib.pyplot as plt

# Exemplo de gráfico de vendas ao longo do tempo
plt.figure(figsize=(10, 6))
vendas_por_data.plot()
plt.title('Vendas ao longo do tempo')
plt.xlabel('Data')
plt.ylabel('Vendas')
plt.grid(True)
plt.show()
# Out:
# Primeiras 5 linhas do DataFrame:
#    data_venda    produto  preco   regiao
# 0  2024-01-01  Produto A    100    Norte
# 1  2024-01-02  Produto B    150      Sul
# 2  2024-01-03  Produto C    120    Leste
# 3  2024-01-04  Produto A    100  Sudeste
# 4  2024-01-05  Produto B    150    Norte
#
# Resumo estatístico do DataFrame:
#             preco
# count   70.000000
# mean   123.000000
# std     20.736441
# min    100.000000
# 25%    100.000000
# 50%    120.000000
# 75%    150.000000
# max    150.000000
#
# Valores nulos por coluna:
# data_venda    0
# produto       0
# preco         0
# regiao        0
# dtype: int64
#
# Vendas ao longo do tempo:
# Index(['data_venda', 'produto', 'preco', 'regiao'], dtype='object')

# %%
print(df.columns)

# %% [markdown]
# data_venda,produto,preco,regiao
# 2024-01-01,Produto A,100,Norte
# 2024-01-02,Produto B,150,Sul
# 2024-01-03,Produto C,120,Leste
# 2024-01-04,Produto A,100,Sudeste
# 2024-01-05,Produto B,150,Norte
# 2024-01-06,Produto C,120,Sul
# 2024-01-07,Produto A,100,Leste
# 2024-01-08,Produto B,150,Nordeste
# 2024-01-09,Produto C,120,Sudeste
# 2024-01-10,Produto A,100,Nordeste
# 2024-01-11,Produto B,150,Sul
# 2024-01-12,Produto C,120,Leste
